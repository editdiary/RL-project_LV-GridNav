# %%
import sys, os
sys.path.append(os.path.abspath('..'))

import numpy as np
from environment.gridworld import GridWorld
from agent.agent import QLearningAgent
from visualize.new_grid_visualize import visualize_gridworld

# 1. 환경 생성
grid_world = GridWorld(
    size=7,
    padding=2,
    seed=40,
    num_walls=5,
    num_construction=5,
    scenario_type="시나리오1"
)

# 2. Q-learning Agent 생성
agent = QLearningAgent()

# 환경 시각화
visualize_gridworld(grid_world)

# %%
episodes = 100000
for episode in range(episodes):
    state = grid_world.reset()

    while True:
        action = agent.get_action(state)
        next_state, reward, done = grid_world.step(action)

        agent.update_policy(state, action, next_state, reward, done)
        if done:
            break
        state = next_state
        
    if episode % (episodes//10) == 0:
        print(f"Episode {episode} / {episodes}")
# Out:
# Episode 0 / 100000
# Episode 10000 / 100000
# Episode 20000 / 100000
# Episode 30000 / 100000
# Episode 40000 / 100000
# Episode 50000 / 100000
# Episode 60000 / 100000
# Episode 70000 / 100000
# Episode 80000 / 100000
# Episode 90000 / 100000

# %%
from visualize.visualize_policy import visualize_policy

# 최적 정책 시각화
visualize_policy(grid_world, agent)

# %%
from visualize.visualize_agent_movement import visualize_agent_movement

# 최적 정책에 따른 에이전트 이동 시각화
visualize_agent_movement(grid_world, agent)
# Out:
# 에이전트가 목표에 도달했습니다. 총 스텝 수: 7

# %% [markdown]
# # 시나리오2

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

import numpy as np
from environment.gridworld import GridWorld
from agent.agent import QLearningAgent
from visualize.new_grid_visualize import visualize_gridworld

# 1. 환경 생성
grid_world = GridWorld(
    size=7,
    padding=2,
    seed=40,
    num_walls=5,
    num_construction=5,
    scenario_type="시나리오2"
)

# 2. Q-learning Agent 생성
agent = QLearningAgent()

# 환경 시각화
visualize_gridworld(grid_world)

# %%
episodes = 100000
for episode in range(episodes):
    state = grid_world.reset()

    while True:
        action = agent.get_action(state)
        next_state, reward, done = grid_world.step(action)

        agent.update_policy(state, action, next_state, reward, done)
        if done:
            break
        state = next_state
        
    if episode % (episodes//10) == 0:
        print(f"Episode {episode} / {episodes}")
# Out:
# Episode 0 / 100000
# Episode 10000 / 100000
# Episode 20000 / 100000
# Episode 30000 / 100000
# Episode 40000 / 100000
# Episode 50000 / 100000
# Episode 60000 / 100000
# Episode 70000 / 100000
# Episode 80000 / 100000
# Episode 90000 / 100000

# %%
from visualize.visualize_policy import visualize_policy

# 최적 정책 시각화
visualize_policy(grid_world, agent)

# %%
from visualize.visualize_agent_movement import visualize_agent_movement

# 최적 정책에 따른 에이전트 이동 시각화
visualize_agent_movement(grid_world, agent)
# Out:
# 에이전트가 목표에 도달했습니다. 총 스텝 수: 4

# %% [markdown]
# # 시나리오3

# %%
import sys, os
sys.path.append(os.path.abspath('..'))

import numpy as np
from environment.gridworld import GridWorld
from agent.agent import QLearningAgent
from visualize.new_grid_visualize import visualize_gridworld

# 1. 환경 생성
grid_world = GridWorld(
    size=7,
    padding=2,
    seed=40,
    num_walls=5,
    num_construction=5,
    scenario_type="시나리오3"
)

# 2. Q-learning Agent 생성
agent = QLearningAgent()

# 환경 시각화
visualize_gridworld(grid_world)

# %%
episodes = 100000
for episode in range(episodes):
    state = grid_world.reset()

    while True:
        action = agent.get_action(state)
        next_state, reward, done = grid_world.step(action)

        agent.update_policy(state, action, next_state, reward, done)
        if done:
            break
        state = next_state
    
    if episode % (episodes//10) == 0:
        print(f"Episode {episode} / {episodes}")
# Out:
# Episode 0 / 100000
# Episode 10000 / 100000
# Episode 20000 / 100000
# Episode 30000 / 100000
# Episode 40000 / 100000
# Episode 50000 / 100000
# Episode 60000 / 100000
# Episode 70000 / 100000
# Episode 80000 / 100000
# Episode 90000 / 100000

# %%
from visualize.visualize_policy import visualize_policy

# 최적 정책 시각화
visualize_policy(grid_world, agent)

# %%
from visualize.visualize_agent_movement import visualize_agent_movement

# 최적 정책에 따른 에이전트 이동 시각화
visualize_agent_movement(grid_world, agent)
# Out:
# 에이전트가 목표에 도달했습니다. 총 스텝 수: 17
